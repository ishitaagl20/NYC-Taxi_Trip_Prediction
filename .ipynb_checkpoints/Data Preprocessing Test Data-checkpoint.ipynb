# %% [markdown]
# # Data Exploration and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from geopy.distance import geodesic
from scipy import stats

# %% [markdown]
# ### Basic Data Exploration

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#           id  vendor_id      pickup_datetime  passenger_count  \
# 0  id3004672          1  2016-06-30 23:59:58                1
# 1  id3505355          1  2016-06-30 23:59:53                1
# 2  id1217141          1  2016-06-30 23:59:47                1
# 3  id2150126          2  2016-06-30 23:59:41                1
# 4  id1598245          1  2016-06-30 23:59:33                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.988129        40.732029         -73.990173         40.756680
# 1        -73.964203        40.679993         -73.959808         40.655403
# 2        -73.997437        40.737583         -73.986160         40.729523
# 3        -73.956070        40.771900         -73.986427         40.730469
# 4        -73.970215        40.761475         -73.961510         40.755890
#
#   store_and_fwd_flag
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N

# %%
data.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  625134.000000    625134.000000     625134.000000    625134.000000
# mean        1.534884         1.661765        -73.973614        40.750927
# std         0.498782         1.311293          0.073389         0.029848
# min         1.000000         0.000000       -121.933128        37.389587
# 25%         1.000000         1.000000        -73.991852        40.737392
# 50%         2.000000         1.000000        -73.981743        40.754093
# 75%         2.000000         2.000000        -73.967400        40.768394
# max         2.000000         9.000000        -69.248917        42.814938
#
#        dropoff_longitude  dropoff_latitude
# count      625134.000000     625134.000000
# mean          -73.973458         40.751816
# std             0.072565          0.035824
# min          -121.933327         36.601322
# 25%           -73.991318         40.736000
# 50%           -73.979774         40.754543
# 75%           -73.963013         40.769852
# max           -67.496796         48.857597

# %%
data.shape
# Out:
# (625134, 9)

# %%
data.isna().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# dtype: object

# %% [markdown]
# ### Data Preprocessing

# %%
data['pickup_datetime'] = pd.to_datetime(data['pickup_datetime'])

# %%
data['week_day'] = data.pickup_datetime.dt.strftime('%A')
data['week_day_num'] = data.pickup_datetime.dt.weekday
data['month'] = data.pickup_datetime.dt.month
data['pickup_hour'] = data.pickup_datetime.dt.hour

# %%
data.head()
# Out:
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id3004672          1 2016-06-30 23:59:58                1
# 1  id3505355          1 2016-06-30 23:59:53                1
# 2  id1217141          1 2016-06-30 23:59:47                1
# 3  id2150126          2 2016-06-30 23:59:41                1
# 4  id1598245          1 2016-06-30 23:59:33                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.988129        40.732029         -73.990173         40.756680
# 1        -73.964203        40.679993         -73.959808         40.655403
# 2        -73.997437        40.737583         -73.986160         40.729523
# 3        -73.956070        40.771900         -73.986427         40.730469
# 4        -73.970215        40.761475         -73.961510         40.755890
#
#   store_and_fwd_flag  week_day  week_day_num  month  pickup_hour
# 0                  N  Thursday             3      6           23
# 1                  N  Thursday             3      6           23
# 2                  N  Thursday             3      6           23
# 3                  N  Thursday             3      6           23
# 4                  N  Thursday             3      6           23

# %%
distance = []
for index in data['pickup_latitude'].index:
    distance.append(geodesic((data['pickup_latitude'].iloc[index], data['pickup_longitude'].iloc[index]), (data['dropoff_latitude'].iloc[index], data['dropoff_longitude'].iloc[index])).kilometers)

data['distance'] = distance

# %%
data.head()

# %%
data['speed_m_s'] = (data['distance'] * 1000)/ data['trip_duration']

# %%
data.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   week_day  \
# 0         40.765602                  N            455     Monday
# 1         40.731152                  N            663     Sunday
# 2         40.710087                  N           2124    Tuesday
# 3         40.706718                  N            429  Wednesday
# 4         40.782520                  N            435   Saturday
#
#    week_day_num  month  pickup_hour  distance  speed_m_s
# 0             0      3           17  1.502172   3.301477
# 1             6      6            0  1.808660   2.727994
# 2             1      1           11  6.379687   3.003619
# 3             2      4           19  1.483632   3.458351
# 4             5      3           13  1.187038   2.728822

# %%
data['speed_km_hr'] = (data['distance'] * 3600) / data['trip_duration']

# %%
data.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   week_day  \
# 0         40.765602                  N            455     Monday
# 1         40.731152                  N            663     Sunday
# 2         40.710087                  N           2124    Tuesday
# 3         40.706718                  N            429  Wednesday
# 4         40.782520                  N            435   Saturday
#
#    week_day_num  month  pickup_hour  distance  speed_m_s  speed_km_hr
# 0             0      3           17  1.502172   3.301477    11.885316
# 1             6      6            0  1.808660   2.727994     9.820778
# 2             1      1           11  6.379687   3.003619    10.813029
# 3             2      4           19  1.483632   3.458351    12.450063
# 4             5      3           13  1.187038   2.728822     9.823760

# %%
data.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# week_day                      object
# week_day_num                   int64
# month                          int64
# pickup_hour                    int64
# distance                     float64
# speed_m_s                    float64
# speed_km_hr                  float64
# dtype: object

# %% [markdown]
# ### Identifying the Outliers

# %%
z_scores = stats.zscore(data['trip_duration'])
threshold = 3
outliers = data[abs(z_scores) > threshold]
print(outliers.shape)
outliers.head()
# Out:
# (2073, 18)
#              id  vendor_id     pickup_datetime    dropoff_datetime  \
# 531   id3307903          2 2016-02-20 04:03:06 2016-02-21 03:33:00
# 1134  id1091477          2 2016-05-07 18:36:22 2016-05-08 18:32:11
# 1865  id3431345          2 2016-06-07 12:58:48 2016-06-08 12:58:00
# 3442  id1487069          2 2016-02-13 00:21:49 2016-02-14 00:19:05
# 4172  id3674870          2 2016-03-18 11:54:20 2016-03-19 11:34:17
#
#       passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 531                 3        -74.008102        40.741489         -74.009956
# 1134                1        -73.990242        40.750919         -73.976280
# 1865                6        -73.954956        40.777649         -73.981033
# 3442                1        -73.968590        40.799217         -73.979584
# 4172                1        -73.989090        40.736992         -73.972336
#
#       dropoff_latitude store_and_fwd_flag  trip_duration  week_day  \
# 531          40.714611                  N          84594  Saturday
# 1134         40.750889                  N          86149  Saturday
# 1865         40.743713                  N          86352   Tuesday
# 3442         40.784714                  N          86236  Saturday
# 4172         40.751511                  N          85197    Friday
#
#       week_day_num  month  pickup_hour  distance  speed_m_s  speed_km_hr
# 531              5      2            4  2.988912   0.035332     0.127197
# 1134             5      5           18  1.179094   0.013687     0.049272
# 1865             1      6           12  4.364658   0.050545     0.181962
# 3442             5      2            0  1.858770   0.021554     0.077596
# 4172             4      3           11  2.145191   0.025179     0.090645

# %%
z_scores = stats.zscore(data['speed_m_s'])
threshold = 3
outliers = data[abs(z_scores) > threshold]
print(outliers.shape)
outliers.head()
# Out:
# (737, 18)
#              id  vendor_id     pickup_datetime    dropoff_datetime  \
# 991   id1859156          1 2016-02-17 00:54:13 2016-02-17 01:36:27
# 1107  id0729156          2 2016-06-23 13:36:48 2016-06-23 13:36:50
# 1383  id1904103          2 2016-06-05 04:58:04 2016-06-05 05:23:19
# 1492  id2456838          1 2016-01-13 20:11:46 2016-01-13 20:11:53
# 1870  id2641288          2 2016-04-03 08:34:32 2016-04-03 08:49:58
#
#       passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 991                 3        -73.969254        40.754047         -73.593582
# 1107                3        -73.827660        40.716175         -73.822113
# 1383                1        -73.777443        40.646641         -73.935776
# 1492                1        -73.793442        40.644814         -73.795242
# 1870                1        -73.789841        40.646961         -73.872818
#
#       dropoff_latitude store_and_fwd_flag  trip_duration   week_day  \
# 991          41.043865                  N           2534  Wednesday
# 1107         40.711452                  N              2   Thursday
# 1383         40.848473                  N           1515     Sunday
# 1492         40.644669                  N              7  Wednesday
# 1870         40.774250                  N            926     Sunday
#
#       week_day_num  month  pickup_hour   distance   speed_m_s  speed_km_hr
# 991              2      2            0  45.143322   17.815044    64.134159
# 1107             3      6           13   0.703342  351.670765  1266.014753
# 1383             6      6            4  26.099120   17.227142    62.017711
# 1492             2      1           20   0.153147   21.878189    78.761479
# 1870             6      4            8  15.778745   17.039681    61.342853

# %%
z_scores = stats.zscore(data['distance'])
threshold = 3
outliers = data[abs(z_scores) > threshold]
print(outliers.shape)
outliers.head()
# Out:
# (40104, 18)
#             id  vendor_id     pickup_datetime    dropoff_datetime  \
# 24   id3321406          2 2016-06-03 08:15:05 2016-06-03 08:56:30
# 50   id2067879          2 2016-01-19 23:19:01 2016-01-19 23:44:58
# 86   id0283075          1 2016-04-06 23:42:26 2016-04-07 00:12:08
# 102  id0105610          1 2016-02-19 20:01:24 2016-02-19 20:35:49
# 104  id3508035          2 2016-06-06 20:13:56 2016-06-06 20:45:20
#
#      passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 24                 1        -73.955231        40.777134         -73.788750
# 50                 1        -73.996819        40.752861         -73.809006
# 86                 1        -73.782478        40.644646         -73.981125
# 102                3        -73.789719        40.643707         -73.978699
# 104                6        -73.788132        40.641460         -73.971771
#
#      dropoff_latitude store_and_fwd_flag  trip_duration   week_day  \
# 24          40.641472                  N           2485     Friday
# 50          40.816875                  N           1557    Tuesday
# 86          40.720886                  N           1782  Wednesday
# 102         40.750343                  N           2065     Friday
# 104         40.749409                  N           1884     Monday
#
#      week_day_num  month  pickup_hour   distance  speed_m_s  speed_km_hr
# 24              4      6            8  20.612408   8.294732    29.861034
# 50              1      1           23  17.373834  11.158532    40.170715
# 86              2      4           23  18.806512  10.553598    37.992953
# 102             4      2           20  19.883300   9.628717    34.663380
# 104             0      6           20  19.611575  10.409541    37.474347

# %%
z_scores = stats.zscore(data['pickup_hour'])
threshold = 3
outliers = data[abs(z_scores) > threshold]
print(outliers.shape)
outliers.head()
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [id, vendor_id, pickup_datetime, dropoff_datetime, passenger_count, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, store_and_fwd_flag, trip_duration, week_day, week_day_num, month, pickup_hour, distance, speed_m_s, speed_km_hr]
# Index: []

# %%
z_scores = stats.zscore(data['week_day_num'])
threshold = 3
outliers = data[abs(z_scores) > threshold]
print(outliers.shape)
outliers.head()
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [id, vendor_id, pickup_datetime, dropoff_datetime, passenger_count, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, store_and_fwd_flag, trip_duration, week_day, week_day_num, month, pickup_hour, distance, speed_m_s, speed_km_hr]
# Index: []

# %%
coordinate_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']
for i in range(len(coordinate_columns)):
    for j in range(i+1, len(coordinate_columns)):
        plt.figure(figsize=(10, 6))
        plt.scatter(data[coordinate_columns[i]], data[coordinate_columns[j]], marker='o', alpha=0.3)
        plt.xlabel(coordinate_columns[i])
        plt.ylabel(coordinate_columns[j])
        plt.title(f'Scatter Plot: {coordinate_columns[i]} vs {coordinate_columns[j]}')
        plt.grid()
        plt.show()

# %%
coordinate_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']
plt.style.use('seaborn-whitegrid')
marker_size = 10
alpha = 0.5
z_threshold = 3
sample_size = 1000
sample_data = data.sample(sample_size)
for i in range(len(coordinate_columns)):
    for j in range(i+1, len(coordinate_columns)):
        plt.figure(figsize=(10, 6))
        plt.scatter(sample_data[coordinate_columns[i]], sample_data[coordinate_columns[j]], marker='o', s=marker_size, alpha=alpha, label='Normal')
        z_scores_i = sample_data[coordinate_columns[i]].apply(lambda x: (x - sample_data[coordinate_columns[i]].mean()) / sample_data[coordinate_columns[i]].std())
        z_scores_j = sample_data[coordinate_columns[j]].apply(lambda x: (x - sample_data[coordinate_columns[j]].mean()) / sample_data[coordinate_columns[j]].std())
        outliers = sample_data[(abs(z_scores_i) > z_threshold) | (abs(z_scores_j) > z_threshold)]
        plt.scatter(outliers[coordinate_columns[i]], outliers[coordinate_columns[j]], marker='o', s=marker_size, alpha=alpha, color='red', label='Outlier')
        plt.xlabel(coordinate_columns[i])
        plt.ylabel(coordinate_columns[j])
        plt.title(f'Scatter Plot: {coordinate_columns[i]} vs {coordinate_columns[j]}')
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
coordinate_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']
z_threshold = 3
z_scores = {}
for column in coordinate_columns:
    z_scores[column] = stats.zscore(data[column])
coordinate_ranges = {}
for column in coordinate_columns:
    lower_bound = data[column][z_scores[column] <= z_threshold].min()
    upper_bound = data[column][z_scores[column] <= z_threshold].max()
    coordinate_ranges[column] = (lower_bound, upper_bound)
coordinate_ranges
# Out:
# {'pickup_longitude': (-121.93334197998048, -73.76089477539062),
#  'pickup_latitude': (34.35969543457031, 40.84952545166016),
#  'dropoff_longitude': (-121.9333038330078, -73.76152038574217),
#  'dropoff_latitude': (32.1811408996582, 40.85947036743164)}

# %%
z_scores = {
    'speed_m_s': stats.zscore(data['speed_m_s']),
    'trip_duration': stats.zscore(data['trip_duration']),
    'distance': stats.zscore(data['distance'])
}
z_threshold = 3
for column, z_scores_array in z_scores.items():
    outliers = data.loc[abs(z_scores_array) > z_threshold]
    data = data.loc[abs(z_scores_array) <= z_threshold]
    print(f"Removed outliers in {column}. New shape: {data.shape}")
coordinate_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']
coordinate_ranges = {}
for column in coordinate_columns:
    lower_bound = data[column].min()
    upper_bound = data[column].max()
    coordinate_ranges[column] = (lower_bound, upper_bound)
print("Calculated Coordinate Ranges:")
print(coordinate_ranges)
for column, (lower, upper) in coordinate_ranges.items():
    data = data[
        (data[column] >= lower) & (data[column] <= upper)
    ]
# Out:
# Removed outliers in speed_m_s. New shape: (1457907, 18)
# Removed outliers in trip_duration. New shape: (1455834, 18)
# Removed outliers in distance. New shape: (1416037, 18)
# Calculated Coordinate Ranges:
# {'pickup_longitude': (-121.93334197998048, -61.33552932739258), 'pickup_latitude': (34.35969543457031, 43.91176223754882), 'dropoff_longitude': (-121.9333038330078, -61.33552932739258), 'dropoff_latitude': (34.35969543457031, 43.91176223754882)}

# %%
data.shape
# Out:
# (1416037, 18)

# %%
data.to_csv('train_preprocessed.csv', index = False)

# %%
preprocessed_data = pd.read_csv('train_preprocessed.csv')
preprocessed_data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   week_day  \
# 0         40.765602                  N            455     Monday
# 1         40.731152                  N            663     Sunday
# 2         40.710087                  N           2124    Tuesday
# 3         40.706718                  N            429  Wednesday
# 4         40.782520                  N            435   Saturday
#
#    week_day_num  month  pickup_hour  distance  speed_m_s  speed_km_hr
# 0             0      3           17  1.502172   3.301477    11.885316
# 1             6      6            0  1.808660   2.727994     9.820778
# 2             1      1           11  6.379687   3.003619    10.813029
# 3             2      4           19  1.483632   3.458351    12.450063
# 4             5      3           13  1.187038   2.728822     9.823760

# %%
preprocessed_data.shape
# Out:
# (1416037, 18)

# %%
data.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# week_day                      object
# week_day_num                   int64
# month                          int64
# pickup_hour                    int64
# distance                     float64
# speed_m_s                    float64
# speed_km_hr                  float64
# dtype: object

# %%
data.describe()
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  1.458644e+06     1.458644e+06      1.458644e+06     1.458644e+06
# mean   1.534950e+00     1.664530e+00     -7.397349e+01     4.075092e+01
# std    4.987772e-01     1.314242e+00      7.090186e-02     3.288119e-02
# min    1.000000e+00     0.000000e+00     -1.219333e+02     3.435970e+01
# 25%    1.000000e+00     1.000000e+00     -7.399187e+01     4.073735e+01
# 50%    2.000000e+00     1.000000e+00     -7.398174e+01     4.075410e+01
# 75%    2.000000e+00     2.000000e+00     -7.396733e+01     4.076836e+01
# max    2.000000e+00     9.000000e+00     -6.133553e+01     5.188108e+01
#
#        dropoff_longitude  dropoff_latitude  trip_duration  week_day_num  \
# count       1.458644e+06      1.458644e+06   1.458644e+06  1.458644e+06
# mean       -7.397342e+01      4.075180e+01   9.594923e+02  3.050375e+00
# std         7.064327e-02      3.589056e-02   5.237432e+03  1.954039e+00
# min        -1.219333e+02      3.218114e+01   1.000000e+00  0.000000e+00
# 25%        -7.399133e+01      4.073588e+01   3.970000e+02  1.000000e+00
# 50%        -7.397975e+01      4.075452e+01   6.620000e+02  3.000000e+00
# 75%        -7.396301e+01      4.076981e+01   1.075000e+03  5.000000e+00
# max        -6.133553e+01      4.392103e+01   3.526282e+06  6.000000e+00
#
#               month   pickup_hour      distance     speed_m_s   speed_km_hr
# count  1.458644e+06  1.458644e+06  1.458644e+06  1.458644e+06  1.458644e+06
# mean   3.516818e+00  1.360648e+01  3.442193e+00  4.007241e+00  1.442607e+01
# std    1.681038e+00  6.399693e+00  4.300259e+00  4.161475e+00  1.498131e+01
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  9.000000e+00  1.232265e+00  2.534558e+00  9.124407e+00
# 50%    4.000000e+00  1.400000e+01  2.094045e+00  3.553834e+00  1.279380e+01
# 75%    5.000000e+00  1.900000e+01  3.874716e+00  4.957068e+00  1.784544e+01
# max    6.000000e+00  2.300000e+01  1.240510e+03  2.577662e+03  9.279582e+03
